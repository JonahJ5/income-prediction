# %% [markdown]
# # 02 Data Cleaning
#
# Runs the pandas cleaning step and writes `data/processed/acs_income_clean.csv` plus the data quality report.

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(PROJECT_ROOT / 'src'))

from clean_ipums import clean_ipums_data

quality_report = clean_ipums_data()
quality_report
