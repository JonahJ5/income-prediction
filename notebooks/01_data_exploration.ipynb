# %% [markdown]
# # 01 Data Exploration
#
# Lightweight exploration notebook for the IPUMS USA / ACS extract. The production workflow lives in `src/run_pipeline.py`.

# %%
from pathlib import Path
import os
import pandas as pd

raw_path = Path(os.getenv('ACS_RAW_PATH', r'C:\Users\jutzi\Downloads\usa_00002.csv\usa_00002.csv'))
sample = pd.read_csv(raw_path, nrows=10000)
sample.head()

# %%
sample.info()
sample.describe(include='all').T.head(30)
